# %% [markdown]
# This notebook is responsible for:
# - Feature correlation analysis and similarity clustering.
# - Evaluating feature importances with a Random Forest regressor and determining the most important feature from similar clusters at a specified similarity threshold.

# %% [markdown]
# # Library Dependencies

# %%
#!pip install -qq ipython numpy pandas scipy scikit-learn xgboost torch

# %%
import sys
import warnings
from pathlib import Path

import matplotlib.pyplot as plt
import seaborn as sns
from IPython.display import display

import numpy as np
import pandas as pd

import sklearn
from sklearn.linear_model import Ridge
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from sklearn.metrics import mean_squared_error, root_mean_squared_error
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline

from collections import Counter
from scipy.cluster import hierarchy
from scipy.cluster.hierarchy import linkage, dendrogram, fcluster
from scipy.spatial.distance import squareform

# %%
# !python --version
print("numpy", np.__version__)
print("pandas", pd.__version__)
print("scikit-learn", sklearn.__version__)
# Out:
# Python 3.10.18
# numpy 2.2.6
# pandas 2.3.3
# scikit-learn 1.7.2

# %% [markdown]
# # Feature Specification, Data Loading, Evaluation Preparation

# %%
# AUTOREGRESSIVE FEATURES
lags = [1, 2, 3, 6, 12, 18, 24, 36, 48, 72, 168]
lagFeatures = [f"Adjusted demand -{h} hr" for h in lags]

# %%
# CALENDAR FEATURES

# Raw integer calendar features
intDateTimeFeatures = ["Hour", "Month", "DayOfWeek", "DayOfYear"]

# Low order hour of day and day of year Fourier term features
hourFourierFeatures, dayFourierFeatures = [], []
for i in (1, 2, 3):
    argStr = (f"{i}*" if i>1 else "") + "Hour"
    hourFourierFeatures.extend([f"sin({argStr})", f"cos({argStr})"])
    argStr = (f"{i}*" if i>1 else "") + "DayOfYear"
    dayFourierFeatures.extend([f"sin({argStr})", f"cos({argStr})"])

# Hour of day and day of week one-hot encodings.
# Weekend and holiday flags.
hourDummyFeatures = [f"Hour_Flag_{h}" for h in range(24)]
dayDummyFeatures = ["Day_Flag_Weekend", "Day_Flag_Holiday"]
dayDummyFeatures += [f"DayOfWeek_Flag_{d}" for d in range(7)]
monthDummyFeatures = [f"Month_Flag_{m}" for m in range(1, 13)]

# Collate all calendar features
calendarFeatures = (
    hourFourierFeatures
    + dayFourierFeatures
    + dayDummyFeatures[:2]
)

# %%
# ENERGY FEATURES

energyFeatures = [
    # "Adjusted net generation",
    # "Adjusted total interchange",
    "FPC", "FMPP", "SOCO", "TEC",
    "JEA", "SEC", "HST", "GVL",
]

# %%
# WEATHER FEATURES

skyCodes = ['BKN', 'CLR', 'FEW', 'SCT', 'OVC', 'NA']
directions = ["N", "NE", "E", "SE", "S", "SW", "W", "NW", "VRB"]

weatherFeatures = ([
    "HourlyDryBulbTemperature",
    "HourlyPrecipitation",
    "HourlyRelativeHumidity",
    "HourlySeaLevelPressure",
    "HourlyVisibility",
    "HourlyWindSpeed"]
    + [f"HourlySkyConditions_Flag_{code}" for code in skyCodes]
    + ["HourlyWindDirection_Flag_VRB",]
    + ["sin(HourlyWindDirection)", "cos(HourlyWindDirection)"]
)

# %%
# Define other convenient feature variables.

allFeatures = (
    lagFeatures 
    + calendarFeatures 
    + energyFeatures 
    + weatherFeatures
)

# %%
# Load data

data_root   = Path("data/clean")
train_dir   = data_root / "train"
val_dir     = data_root / "val"
fig_root = Path("figures")
fig_root.mkdir(parents=True, exist_ok=True)

DFtrain = pd.read_pickle(train_dir / "DFtrain.pkl")
TARGET_COL   = "Adjusted demand"
TIME_COL     = "t"
FEATURE_COLS = allFeatures

print("n_train:", len(DFtrain))
print("n_features:", len(FEATURE_COLS))
# Out:
# n_train: 59647
# n_features: 48

# %% [markdown]
# # Correlation Analysis and Clustering

# %%
# Correlation heatmap.

# Spearman correlation (absolute value)
corr = DFtrain[FEATURE_COLS].corr(method="spearman").abs()
mask = np.triu(np.ones_like(corr, dtype=bool))
n_features = corr.shape[0]

# Make the figure wide enough to fit all labels
fig_width  = max(8, 0.3 * n_features)
fig_height = max(4, 0.22 * n_features)   # ↓ smaller factor + lower minimum

fig, ax = plt.subplots(figsize=(fig_width, fig_height))

sns.heatmap(
    corr,
    mask=mask,
    cmap="viridis",
    vmin=0, vmax=1,
    square=True,
    linewidths=0.5,
    cbar_kws={"label": "|Spearman ρ|"},
    annot=False,
    ax=ax
)

positions = np.arange(n_features) + 0.5
ax.set_xticks(positions)
ax.set_yticks(positions)

ax.set_xticklabels(corr.columns, fontsize=8, rotation=90)
ax.set_yticklabels(corr.index,   fontsize=8, rotation=0)
ax.tick_params(axis="both", length=0)

# Title closer to the plot
ax.set_title("Feature Correlation Heatmap (|Spearman ρ|)", fontsize=12, pad=4)

# Reduce top margin a bit
plt.tight_layout(rect=(0, 0, 1, 0.96))
plt.savefig("figures/CorrelationHeatmap", bbox_inches='tight')
plt.show()

# %%
# Random Forest feature importances.

# Reproducibility
np.random.seed(42)

# Load feature selection raw data
X_fs = DFtrain[FEATURE_COLS]
y_fs = DFtrain[TARGET_COL]

# Fit random forest model
fs_model = RandomForestRegressor(n_estimators=50, random_state=42)
fs_model.fit(X_fs, y_fs)

# Show feature importance scores
print("Feature importance scores:\n", fs_model.feature_importances_)

# Plot feature importance scores
fs_plot_names = FEATURE_COLS
fs_plot_ticks = fs_plot_names

fig, ax = plt.subplots(figsize=(10,10))
bars = ax.barh(fs_plot_ticks, fs_model.feature_importances_)
ax.bar_label(bars)
ax.set_yticks(fs_plot_ticks, fs_plot_names)
ax.set_xscale('linear')
plt.xlabel('Importance')
plt.title('Feature Importances')
plt.show()

fig, ax = plt.subplots(figsize=(10,10))
bars = ax.barh(fs_plot_ticks, fs_model.feature_importances_)
ax.bar_label(bars)
ax.set_yticks(fs_plot_ticks, fs_plot_names)
ax.set_xscale('log')
plt.xlabel('Importance')
plt.title('Feature Importances')
plt.savefig("figures/FeatureImportances", bbox_inches='tight')
plt.show()
# Out:
# Feature importance scores:
#  [9.23305686e-01 2.91117770e-03 2.37588325e-03 1.43901703e-03
#  8.99277127e-04 6.97266303e-03 3.10937200e-02 3.42949373e-04
#  5.12024154e-04 2.68930915e-04 3.21488946e-04 5.55812813e-04
#  6.68403064e-03 5.73485669e-04 5.86620380e-03 5.92138644e-04
#  6.96838466e-03 2.48827686e-04 2.11949694e-04 1.96839973e-04
#  1.71900945e-04 1.96609232e-04 1.39695862e-04 1.48396490e-04
#  8.19253320e-06 2.87364051e-04 2.23906189e-04 3.41179061e-04
#  2.06799275e-04 1.96668485e-04 3.15962825e-04 9.03471448e-04
#  1.53808669e-04 3.30531043e-03 3.72782631e-05 1.71352626e-04
#  1.93688001e-04 1.16491090e-04 8.63789018e-05 2.04016900e-05
#  4.96799615e-05 2.63129666e-05 3.63406158e-05 1.32392811e-05
#  1.74111987e-05 2.41243009e-05 1.39118037e-04 1.28426818e-04]

# %%
# Feature selection using hierarchical clustering on spearman similarity
#  and feature importances from the RF model.


fs_corr = X_fs.corr(method="spearman")
fs_dist = 1.0 - fs_corr.abs()

DF_clusters = linkage(squareform(fs_dist.values, checks=False), method="average")

fs_dist_max = 0.5 # Set maximum distance.

fig, ax = plt.subplots(figsize=(10,10))
plt.title('Hierarchical Clustering Dendrogram')
plt.ylabel('Distance = 1 - SpearmanCorrelation')
fs_dendrogram_v = dendrogram(DF_clusters, color_threshold=fs_dist_max, above_threshold_color='grey', orientation='top')
plt.axhline(y=fs_dist_max, c='k', dashes=(5,5))
plt.show()

fig, ax = plt.subplots(figsize=(10,10))
plt.title('Hierarchical Clustering Dendrogram')
plt.xlabel('Distance = 1 - SpearmanCorrelation')
fs_dendrogram_h = dendrogram(DF_clusters, color_threshold=fs_dist_max, above_threshold_color='grey', orientation='right', labels=FEATURE_COLS)
plt.axvline(x=fs_dist_max, c='k', dashes=(5,5))
plt.savefig("figures/FeatureClusters", bbox_inches='tight')
plt.show()

fs_fcluster = fcluster(DF_clusters, t=fs_dist_max, criterion='distance')
print('Flat Clusters :', fs_fcluster)

allFeatsClusters = []
fs_num_clusters = len(Counter(fs_fcluster).keys())
fs_num_leaves = len(fs_fcluster)

for i in range(fs_num_clusters):
    allFeatsClusters.append([])

for i in range(fs_num_leaves):
    allFeatsClusters[fs_fcluster[i]-1].append(FEATURE_COLS[i])

for i in range(fs_num_clusters):
    print('Cluster', i+1, ':', allFeatsClusters[i])
print()

selectedFeats = []
y_fs_c = DFtrain[TARGET_COL]
for c in allFeatsClusters:
    if (len(c) < 1):
        print('Error: Cluster', c, 'has size < 1.')
        continue # Skip forward.
    elif (len(c) == 1):
        print('Feature importance of cluster', c, 'skipped with size = 1.')
        selectedFeats.append(c[0])
        continue # Skip forward.
    else:
        print('Feature importance of cluster', c, ':')
    
    # Load feature selection raw data
    X_fs_c = DFtrain[c]
    
    # Fit random forest model
    fs_c_model = RandomForestRegressor(n_estimators=50, random_state=42)
    fs_c_model.fit(X_fs_c, y_fs_c)
    
    # Show feature importance scores
    fs_c_importances = fs_c_model.feature_importances_
    print(fs_c_importances)
    
    # Select a feature with the highest importance
    fs_c_index = 0
    fs_c_importance_max = 0
    for i in range(len(fs_c_importances)):
        if (fs_c_importances[i] >= fs_c_importance_max):
            fs_c_importance_max = fs_c_importances[i]
            fs_c_index = i
    
    selectedFeats.append(c[fs_c_index])
print()

print('Selected features :', selectedFeats)
# Out:
# Flat Clusters : [11 11 11  8 10  8 11 10 11 11 11 10  8 10  8 10  8  3 14 27 18 28 29  1
#   2 11 15 11 16 17 12 11 13 11 19  9  4 21  5 23 25 21 22 20 24 26  6  7]
# Cluster 1 : ['Day_Flag_Weekend']
# Cluster 2 : ['Day_Flag_Holiday']
# Cluster 3 : ['sin(DayOfYear)']
# Cluster 4 : ['HourlySeaLevelPressure']
# Cluster 5 : ['HourlyWindSpeed']
# Cluster 6 : ['sin(HourlyWindDirection)']
# Cluster 7 : ['cos(HourlyWindDirection)']
# Cluster 8 : ['Adjusted demand -6 hr', 'Adjusted demand -18 hr', 'cos(Hour)', 'cos(2*Hour)', 'cos(3*Hour)']
# Cluster 9 : ['HourlyRelativeHumidity']
# Cluster 10 : ['Adjusted demand -12 hr', 'Adjusted demand -36 hr', 'sin(Hour)', 'sin(2*Hour)', 'sin(3*Hour)']
# Cluster 11 : ['Adjusted demand -1 hr', 'Adjusted demand -2 hr', 'Adjusted demand -3 hr', 'Adjusted demand -24 hr', 'Adjusted demand -48 hr', 'Adjusted demand -72 hr', 'Adjusted demand -168 hr', 'FPC', 'SOCO', 'HST', 'HourlyDryBulbTemperature']
# Cluster 12 : ['SEC']
# Cluster 13 : ['GVL']
# Cluster 14 : ['cos(DayOfYear)']
# Cluster 15 : ['FMPP']
# Cluster 16 : ['TEC']
# Cluster 17 : ['JEA']
# Cluster 18 : ['cos(2*DayOfYear)']
# Cluster 19 : ['HourlyPrecipitation']
# Cluster 20 : ['HourlySkyConditions_Flag_OVC']
# Cluster 21 : ['HourlyVisibility', 'HourlySkyConditions_Flag_FEW']
# Cluster 22 : ['HourlySkyConditions_Flag_SCT']
# Cluster 23 : ['HourlySkyConditions_Flag_BKN']
# Cluster 24 : ['HourlySkyConditions_Flag_NA']
# Cluster 25 : ['HourlySkyConditions_Flag_CLR']
# Cluster 26 : ['HourlyWindDirection_Flag_VRB']
# Cluster 27 : ['sin(2*DayOfYear)']
# Cluster 28 : ['sin(3*DayOfYear)']
# Cluster 29 : ['cos(3*DayOfYear)']
#
# Feature importance of cluster ['Day_Flag_Weekend'] skipped with size = 1.
# Feature importance of cluster ['Day_Flag_Holiday'] skipped with size = 1.
# Feature importance of cluster ['sin(DayOfYear)'] skipped with size = 1.
# Feature importance of cluster ['HourlySeaLevelPressure'] skipped with size = 1.
# Feature importance of cluster ['HourlyWindSpeed'] skipped with size = 1.
# Feature importance of cluster ['sin(HourlyWindDirection)'] skipped with size = 1.
# Feature importance of cluster ['cos(HourlyWindDirection)'] skipped with size = 1.
# Feature importance of cluster ['Adjusted demand -6 hr', 'Adjusted demand -18 hr', 'cos(Hour)', 'cos(2*Hour)', 'cos(3*Hour)'] :
# [0.46667381 0.17074625 0.10662957 0.10461848 0.1513319 ]
# Feature importance of cluster ['HourlyRelativeHumidity'] skipped with size = 1.
# Feature importance of cluster ['Adjusted demand -12 hr', 'Adjusted demand -36 hr', 'sin(Hour)', 'sin(2*Hour)', 'sin(3*Hour)'] :
# [0.34270437 0.23042282 0.12647333 0.10872686 0.19167263]
# Feature importance of cluster ['Adjusted demand -1 hr', 'Adjusted demand -2 hr', 'Adjusted demand -3 hr', 'Adjusted demand -24 hr', 'Adjusted demand -48 hr', 'Adjusted demand -72 hr', 'Adjusted demand -168 hr', 'FPC', 'SOCO', 'HST', 'HourlyDryBulbTemperature'] :
# [9.23828855e-01 5.50574348e-03 1.68880704e-02 3.82924898e-02
#  9.69035244e-04 7.65248282e-04 9.15632538e-04 7.74888285e-04
#  8.15848015e-04 1.49752263e-03 9.74666651e-03]
# Feature importance of cluster ['SEC'] skipped with size = 1.
# Feature importance of cluster ['GVL'] skipped with size = 1.
# Feature importance of cluster ['cos(DayOfYear)'] skipped with size = 1.
# Feature importance of cluster ['FMPP'] skipped with size = 1.
# Feature importance of cluster ['TEC'] skipped with size = 1.
# Feature importance of cluster ['JEA'] skipped with size = 1.
# Feature importance of cluster ['cos(2*DayOfYear)'] skipped with size = 1.
# Feature importance of cluster ['HourlyPrecipitation'] skipped with size = 1.
# Feature importance of cluster ['HourlySkyConditions_Flag_OVC'] skipped with size = 1.
# Feature importance of cluster ['HourlyVisibility', 'HourlySkyConditions_Flag_FEW'] :
# [0.81779799 0.18220201]
# Feature importance of cluster ['HourlySkyConditions_Flag_SCT'] skipped with size = 1.
# Feature importance of cluster ['HourlySkyConditions_Flag_BKN'] skipped with size = 1.
# Feature importance of cluster ['HourlySkyConditions_Flag_NA'] skipped with size = 1.
# Feature importance of cluster ['HourlySkyConditions_Flag_CLR'] skipped with size = 1.
# Feature importance of cluster ['HourlyWindDirection_Flag_VRB'] skipped with size = 1.
# Feature importance of cluster ['sin(2*DayOfYear)'] skipped with size = 1.
# Feature importance of cluster ['sin(3*DayOfYear)'] skipped with size = 1.
# Feature importance of cluster ['cos(3*DayOfYear)'] skipped with size = 1.
#
# Selected features : ['Day_Flag_Weekend', 'Day_Flag_Holiday', 'sin(DayOfYear)', 'HourlySeaLevelPressure', 'HourlyWindSpeed', 'sin(HourlyWindDirection)', 'cos(HourlyWindDirection)', 'Adjusted demand -6 hr', 'HourlyRelativeHumidity', 'Adjusted demand -12 hr', 'Adjusted demand -1 hr', 'SEC', 'GVL', 'cos(DayOfYear)', 'FMPP', 'TEC', 'JEA', 'cos(2*DayOfYear)', 'HourlyPrecipitation', 'HourlySkyConditions_Flag_OVC', 'HourlyVisibility', 'HourlySkyConditions_Flag_SCT', 'HourlySkyConditions_Flag_BKN', 'HourlySkyConditions_Flag_NA', 'HourlySkyConditions_Flag_CLR', 'HourlyWindDirection_Flag_VRB', 'sin(2*DayOfYear)', 'sin(3*DayOfYear)', 'cos(3*DayOfYear)']
