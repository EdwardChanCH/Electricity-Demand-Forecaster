# %% [markdown]
# # Q1 - Data Loading

# %%
from pathlib import Path
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

pd.set_option('display.max_rows', None)
df_elec = pd.read_csv('FPL.csv', low_memory = False)
df_weather = pd.read_csv('MIA_2024.csv', low_memory = False)

# %%
(df_elec.isnull().sum() * 100 / len(df_elec))
# Out:
# BA                                                     0.000000
# UTC time                                               0.000000
# Local date                                             0.000000
# Hour                                                   0.000000
# Local time                                             0.000000
# Time zone                                              0.000000
# Generation only?                                       0.000000
# Demand forecast                                        0.258552
# Demand                                                 0.945815
# Net generation                                         0.945815
# Total interchange                                      0.183417
# Imputed demand                                        99.093963
# Imputed net generation                                99.651949
# Imputed total interchange                             99.996685
# Adjusted demand                                        0.053036
# ...

# %%
(df_weather.isnull().sum() * 100 / len(df_weather))
# Out:
# STATION                                           0.000000
# DATE                                              0.000000
# LATITUDE                                          0.000000
# LONGITUDE                                         0.000000
# ELEVATION                                         0.000000
# NAME                                              0.000000
# REPORT_TYPE                                       0.000000
# SOURCE                                            0.000000
# HourlyAltimeterSetting                           23.853491
# HourlyDewPointTemperature                         2.716520
# HourlyDryBulbTemperature                          2.716520
# HourlyPrecipitation                              34.070965
# HourlyPresentWeatherType                         90.850820
# HourlyPressureChange                             56.711179
# HourlyPressureTendency                           56.711179
# HourlyRelativeHumidity                            2.716520
# ...

# %%
df_weather.isnull().sum()
# Out:
# STATION                                             0
# DATE                                                0
# LATITUDE                                            0
# LONGITUDE                                           0
# ELEVATION                                           0
# NAME                                                0
# REPORT_TYPE                                         0
# SOURCE                                              0
# HourlyAltimeterSetting                           3126
# HourlyDewPointTemperature                         356
# HourlyDryBulbTemperature                          356
# HourlyPrecipitation                              4465
# HourlyPresentWeatherType                        11906
# HourlyPressureChange                             7432
# HourlyPressureTendency                           7432
# HourlyRelativeHumidity                            356
# HourlySkyConditions                              1529
# ...

# %%
plt.figure(figsize=(15, 15))
sns.heatmap(df_weather.isnull(), cbar=False, cmap='viridis')
plt.title('Heatmap of Missing Values in the Dataset')
plt.xlabel('Columns')
plt.ylabel('Rows')

plt.show()

# %%
cols = ['HourlyAltimeterSetting', 'HourlyDewPointTemperature', 'HourlyDryBulbTemperature', 'HourlyPrecipitation', 'HourlyPresentWeatherType', 'HourlyPressureChange', 'HourlyPressureTendency', 'HourlyRelativeHumidity', 'HourlySeaLevelPressure', 'HourlyStationPressure', 'HourlyVisibility', 'HourlyWetBulbTemperature', 'HourlyWindDirection', 'HourlyWindGustSpeed']

sns.heatmap(df_weather[cols].isnull().T, cbar=False, cmap='viridis')
plt.title('Heatmap of Missing Values in the Dataset')
plt.xlabel('Columns')
plt.ylabel('Rows')

plt.show()

# %% [markdown]
# HourlyStationPressure and HourlyWetBulbTemperature has the same null values

# %%
sns.heatmap(df_weather.corr(numeric_only=True), annot=True, cmap='coolwarm', fmt='.2f')
plt.show()
